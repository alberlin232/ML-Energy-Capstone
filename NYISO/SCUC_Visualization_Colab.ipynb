# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# !pwd
# !ls
# Out:
# Mounted at /content/drive
# /content
# drive  sample_data

# %%
os.chdir(f'/content/drive/My Drive/scuc_data/Output_folder_Aug2019')

# !pwd
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/14V_XiVwiqjDp_sT0bkW1s0dcsL-n-2Xt/scuc_data/Output_folder_Aug2019
# Excel_educ_fr_0802  Excel_educ_fr_0808		output_educ_ny_fr_0807.mat
# Excel_educ_fr_0803  output_educ_ny_fr_0802.mat	output_educ_ny_fr_0808.mat
# Excel_educ_fr_0804  output_educ_ny_fr_0803.mat	Overall_results_week.csv
# Excel_educ_fr_0805  output_educ_ny_fr_0804.mat	Wind_dispatch_week.csv
# Excel_educ_fr_0806  output_educ_ny_fr_0805.mat
# Excel_educ_fr_0807  output_educ_ny_fr_0806.mat

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv (r'/content/drive/My Drive/scuc_data/Output_folder_Aug2019/Overall_results_week.csv')

# %%
colorb = {'coal': (.7969,.7969,.7969),
          'hydro': (0,0,.8),
          'ng': (0.9961,0.75,.1484),
          'ngcc': (0.52,0.8,.98),
          'nuclear': (0.7969,0,0),
          'other': (0.2,0.2,.2),
          'rfo': (0.2031,0.2852,.3672),
          'wind': (0,.5,0),
          'wood': (0.6445,0.1641,.1641),
          'solar': (0.9727,0.8398,.1094),
         }

# %%
print(df)
# Out:
#     Row    Tot Gen(MW)  Tot Demand(MW)   Rnw Gen(MW)  Disp Cost($)  \
# 0  Day1  540638.857659   540638.857659   8853.019747  8.218741e+06
# 1  Day2  522553.980187   522553.980188   9764.090546  7.818308e+06
# 2  Day3  514806.879742   514806.879741  10197.405389  7.697953e+06
# 3  Day4  529806.753813   529806.753920   9595.043071  7.976078e+06
# 4  Day5  542923.480368   542923.480368  10425.534821  8.245352e+06
# 5  Day6  552437.302535   552437.302374   8633.088636  8.490253e+06
# 6  Day7  548971.733888   548971.733870  10658.888217  8.365732e+06
#
#    Res Cost($)   Tot Cost($)
# 0        31440  8.250181e+06
# 1        31440  7.849748e+06
# 2        31440  7.729393e+06
# 3        31440  8.007518e+06
# 4        31440  8.276792e+06
# 5        31440  8.521693e+06
# 6        31440  8.397172e+06

# %%
width = .35

fig, ax = plt.subplots()

ax.bar(df['Row'], df['Rnw Gen(MW)'], width, label='Rnw Gen(MW)')
ax.bar(df['Row'], df['Tot Demand(MW)']-df['Rnw Gen(MW)'], width, bottom=df['Rnw Gen(MW)'], label='Tot Demand(MW)')

ax.set_ylabel('MW')
ax.set_title('Total Demand over Renewable Generation Weekly')
plt.ylim(0,df['Tot Demand(MW)'].max()+150000)
ax.legend()

plt.show()

# %%
color_map1 = ["#CC0000", "#0000CC"]
color_map2 = ["#FFC026", "#CCCCCC"]
color_map22 = ["#CCCCCC", "#FFC026"]
color_map3 = ["#34495E", "#9b59b6"]
color_map4 = ["#008000", "#f9d71c"]
fig, ax = plt.subplots()
plt.stackplot(df['Row'],df['Rnw Gen(MW)'], df['Tot Demand(MW)']-df['Rnw Gen(MW)'], labels=['Rnw Gen(MW)','Tot Demand(MW)'], colors=color_map2)
ax.set_ylabel('MW')
ax.set_title('Total Demand over Renewable Generation Weekly')
plt.ylim(0,df['Tot Demand(MW)'].max()+150000)
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
plt.stackplot(df['Row'],df['Disp Cost($)'], df['Res Cost($)'], labels=['Disp Cost($)','Res Cost($)'], colors=color_map22)
ax.set_ylabel('Dollars')
ax.set_title('Total Cost Weekly')
plt.ylim(0,df['Tot Cost($)'].max()+2000000)
plt.legend()
plt.show()

# %%
aug2 = pd.read_csv (r'/content/drive/My Drive/scuc_data/Output_folder_Aug2019/Excel_educ_fr_0802/Disp_educ_fr_fueltype.csv')
aug2_sum = aug2.sum(axis=0)
aug3 = pd.read_csv (r'/content/drive/My Drive/scuc_data/Output_folder_Aug2019/Excel_educ_fr_0803/Disp_educ_fr_fueltype.csv')
aug3_sum = aug3.sum(axis=0)
aug4 = pd.read_csv (r'/content/drive/My Drive/scuc_data/Output_folder_Aug2019/Excel_educ_fr_0804/Disp_educ_fr_fueltype.csv')
aug4_sum = aug4.sum(axis=0)
aug5 = pd.read_csv (r'/content/drive/My Drive/scuc_data/Output_folder_Aug2019/Excel_educ_fr_0805/Disp_educ_fr_fueltype.csv')
aug5_sum = aug5.sum(axis=0)
aug6 = pd.read_csv (r'/content/drive/My Drive/scuc_data/Output_folder_Aug2019/Excel_educ_fr_0806/Disp_educ_fr_fueltype.csv')
aug6_sum = aug6.sum(axis=0)
aug7 = pd.read_csv (r'/content/drive/My Drive/scuc_data/Output_folder_Aug2019/Excel_educ_fr_0807/Disp_educ_fr_fueltype.csv')
aug7_sum = aug7.sum(axis=0)
aug8 = pd.read_csv (r'/content/drive/My Drive/scuc_data/Output_folder_Aug2019/Excel_educ_fr_0808/Disp_educ_fr_fueltype.csv')
aug8_sum = aug8.sum(axis=0)

# %%
width = .35

fig, ax = plt.subplots()

ax.bar(aug2.columns, aug2_sum)

ax.set_ylabel('MW')
ax.set_title('Aug 2nd Generation Sources')

plt.show()

# %%
fig, ax = plt.subplots()

ax.bar(aug3.columns, aug3_sum)

ax.set_ylabel('MW')
ax.set_title('Aug 3rd Generation Sources')

plt.show()

# %%
fig, ax = plt.subplots()

ax.bar(aug4.columns, aug4_sum)

ax.set_ylabel('MW')
ax.set_title('Aug 4th Generation Sources')

plt.show()

# %%
fig, ax = plt.subplots()

ax.bar(aug5.columns, aug5_sum)

ax.set_ylabel('MW')
ax.set_title('Aug 5th Generation Sources')

plt.show()

# %%
fig, ax = plt.subplots()

ax.bar(aug6.columns, aug6_sum)

ax.set_ylabel('MW')
ax.set_title('Aug 6th Generation Sources')

plt.show()

# %%
fig, ax = plt.subplots()

ax.bar(aug7.columns, aug7_sum)

ax.set_ylabel('MW')
ax.set_title('Aug 7th Generation Sources')

plt.show()

# %%
fig, ax = plt.subplots()

ax.bar(aug8.columns, aug8_sum)

ax.set_ylabel('MW')
ax.set_title('Aug 8th Generation Sources')

plt.show()

# %%
fig, axs = plt.subplots(4, 2)
fig.set_figheight(30)
fig.set_figwidth(30)
fig.suptitle('Generation Sources by Day', size=50)
axs[0,0].set_title('Aug 2nd', fontdict={'fontsize':30})
axs[0,0].set_ylabel('MW', fontdict={'fontsize':30})
axs[0,0].bar(aug2.columns, aug2_sum)
axs[0,0].tick_params(axis='x', labelsize=20)

axs[0,1].set_title('Aug 3rd', fontdict={'fontsize':30})
axs[0,1].set_ylabel('MW', fontdict={'fontsize':30})
axs[0,1].bar(aug3.columns, aug3_sum)
axs[0,1].tick_params(axis='x', labelsize=20)

axs[1,0].set_title('Aug 4th', fontdict={'fontsize':30})
axs[1,0].set_ylabel('MW', fontdict={'fontsize':30})
axs[1,0].bar(aug4.columns, aug4_sum)
axs[1,0].tick_params(axis='x', labelsize=20)

axs[1,1].set_title('Aug 5th', fontdict={'fontsize':30})
axs[1,1].set_ylabel('MW', fontdict={'fontsize':30})
axs[1,1].bar(aug5.columns, aug5_sum)
axs[1,1].tick_params(axis='x', labelsize=20)

axs[2,0].set_title('Aug 6th', fontdict={'fontsize':30})
axs[2,0].set_ylabel('MW', fontdict={'fontsize':30})
axs[2,0].bar(aug6.columns, aug6_sum)
axs[2,0].tick_params(axis='x', labelsize=20)

axs[2,1].set_title('Aug 7th', fontdict={'fontsize':30})
axs[2,1].set_ylabel('MW', fontdict={'fontsize':30})
axs[2,1].bar(aug7.columns, aug7_sum)
axs[2,1].tick_params(axis='x', labelsize=20)

axs[3,0].set_title('Aug 8th', fontdict={'fontsize':30})
axs[3,0].set_ylabel('MW', fontdict={'fontsize':30})
axs[3,0].bar(aug8.columns, aug8_sum)
axs[3,0].tick_params(axis='x', labelsize=20)
#plt.subplots_adjust(wspace = .5, hspace = .5)
#plt.subplots_adjust(left=0.5, bottom=0.5, right=1, top=1, wspace=0.9,hspace=0.9)
#fig.tight_layout()
plt.show()

# %%
aug2c = pd.read_csv (r'/content/drive/My Drive/scuc_data/Output_folder_Aug2019/Excel_educ_fr_0802/Disp_educ_cost_fr_fueltype.csv')
aug3c = pd.read_csv (r'/content/drive/My Drive/scuc_data/Output_folder_Aug2019/Excel_educ_fr_0802/Disp_educ_cost_fr_fueltype.csv')
aug4c = pd.read_csv (r'/content/drive/My Drive/scuc_data/Output_folder_Aug2019/Excel_educ_fr_0802/Disp_educ_cost_fr_fueltype.csv')
aug5c = pd.read_csv (r'/content/drive/My Drive/scuc_data/Output_folder_Aug2019/Excel_educ_fr_0802/Disp_educ_cost_fr_fueltype.csv')
aug6c = pd.read_csv (r'/content/drive/My Drive/scuc_data/Output_folder_Aug2019/Excel_educ_fr_0802/Disp_educ_cost_fr_fueltype.csv')
aug7c = pd.read_csv (r'/content/drive/My Drive/scuc_data/Output_folder_Aug2019/Excel_educ_fr_0802/Disp_educ_cost_fr_fueltype.csv')
aug8c = pd.read_csv (r'/content/drive/My Drive/scuc_data/Output_folder_Aug2019/Excel_educ_fr_0802/Disp_educ_cost_fr_fueltype.csv')

# %%
aug2c = aug2c.drop(['Avg_Nuclear', 'Avg_NG', 'Avg_RFO', 'Avg_Hydro', 'Avg_Coal', 'Avg_wood', 'Avg_Wind', 'Avg_Other'], axis=1)
aug3c = aug3c.drop(['Avg_Nuclear', 'Avg_NG', 'Avg_RFO', 'Avg_Hydro', 'Avg_Coal', 'Avg_wood', 'Avg_Wind', 'Avg_Other'], axis=1)
aug4c = aug4c.drop(['Avg_Nuclear', 'Avg_NG', 'Avg_RFO', 'Avg_Hydro', 'Avg_Coal', 'Avg_wood', 'Avg_Wind', 'Avg_Other'], axis=1)
aug5c = aug5c.drop(['Avg_Nuclear', 'Avg_NG', 'Avg_RFO', 'Avg_Hydro', 'Avg_Coal', 'Avg_wood', 'Avg_Wind', 'Avg_Other'], axis=1)
aug6c = aug6c.drop(['Avg_Nuclear', 'Avg_NG', 'Avg_RFO', 'Avg_Hydro', 'Avg_Coal', 'Avg_wood', 'Avg_Wind', 'Avg_Other'], axis=1)
aug7c = aug7c.drop(['Avg_Nuclear', 'Avg_NG', 'Avg_RFO', 'Avg_Hydro', 'Avg_Coal', 'Avg_wood', 'Avg_Wind', 'Avg_Other'], axis=1)
aug8c = aug8c.drop(['Avg_Nuclear', 'Avg_NG', 'Avg_RFO', 'Avg_Hydro', 'Avg_Coal', 'Avg_wood', 'Avg_Wind', 'Avg_Other'], axis=1)
aug2_sumc = aug2c.sum(axis=0)
aug3_sumc = aug3c.sum(axis=0)
aug4_sumc = aug4c.sum(axis=0)
aug5_sumc = aug5c.sum(axis=0)
aug6_sumc = aug6c.sum(axis=0)
aug7_sumc = aug7c.sum(axis=0)
aug8_sumc = aug8c.sum(axis=0)

# %%
fig, ax = plt.subplots()

ax.bar(aug2c.columns, aug2_sumc)

ax.set_ylabel('Dollars ($)')
ax.set_title('Aug 2nd Generation Source Total Costs')

plt.show()

# %%
print(aug2_sumc)
print(aug3_sumc)
print(aug4_sumc)
print(aug5_sumc)
print(aug6_sumc)
print(aug7_sumc)
print(aug8_sumc)
# Out:
# Nuclear    5.037046e+05
# NG         6.390981e+06
# RFO        1.133293e+04
# Hydro      1.081442e+06
# Coal       2.312796e+05
# Wood       0.000000e+00
# Wind       0.000000e+00
# Other      0.000000e+00
# dtype: float64
# Nuclear    5.037046e+05
# NG         5.990624e+06
# RFO        1.125740e+04
# Hydro      1.081442e+06
# Coal       2.312796e+05
# Wood       0.000000e+00
# Wind       0.000000e+00
# Other      0.000000e+00
# dtype: float64
# Nuclear    5.037046e+05
# NG         5.870269e+06
# RFO        1.125740e+04
# Hydro      1.081442e+06
# Coal       2.312796e+05
# Wood       0.000000e+00
# Wind       0.000000e+00
# Other      0.000000e+00
# dtype: float64
# Nuclear    5.037046e+05
# NG         6.148168e+06
# RFO        1.148400e+04
# Hydro      1.081442e+06
# Coal       2.312796e+05
# Wood       0.000000e+00
# Wind       0.000000e+00
# Other      0.000000e+00
# dtype: float64
# Nuclear    5.037046e+05
# NG         6.417668e+06
# RFO        1.125740e+04
# ...

# %%
fig, ax = plt.subplots()

ax.bar(aug3c.columns, aug3_sumc)

ax.set_ylabel('Dollars ($)')
ax.set_title('Aug 3rd Generation Source Total Costs')

plt.show()

# %%
fig, axs = plt.subplots(4, 2)
fig.set_figheight(30)
fig.set_figwidth(30)
fig.suptitle('Generation Total Cost by Sources by Day', size=50)
axs[0,0].set_title('Aug 2nd', fontdict={'fontsize':30})
axs[0,0].set_ylabel('Dollars ($)', fontdict={'fontsize':30})
axs[0,0].bar(aug2c.columns, aug2_sumc)
axs[0,0].tick_params(axis='x', labelsize=20)

axs[0,1].set_title('Aug 3rd', fontdict={'fontsize':30})
axs[0,1].set_ylabel('Dollars ($)', fontdict={'fontsize':30})
axs[0,1].bar(aug3c.columns, aug3_sumc)
axs[0,1].tick_params(axis='x', labelsize=20)

axs[1,0].set_title('Aug 4th', fontdict={'fontsize':30})
axs[1,0].set_ylabel('Dollars ($)', fontdict={'fontsize':30})
axs[1,0].bar(aug4c.columns, aug4_sumc)
axs[1,0].tick_params(axis='x', labelsize=20)

axs[1,1].set_title('Aug 5th', fontdict={'fontsize':30})
axs[1,1].set_ylabel('Dollars ($)', fontdict={'fontsize':30})
axs[1,1].bar(aug5c.columns, aug5_sumc)
axs[1,1].tick_params(axis='x', labelsize=20)

axs[2,0].set_title('Aug 6th', fontdict={'fontsize':30})
axs[2,0].set_ylabel('Dollars ($)', fontdict={'fontsize':30})
axs[2,0].bar(aug6c.columns, aug6_sumc)
axs[2,0].tick_params(axis='x', labelsize=20)

axs[2,1].set_title('Aug 7th', fontdict={'fontsize':30})
axs[2,1].set_ylabel('Dollars ($)', fontdict={'fontsize':30})
axs[2,1].bar(aug7c.columns, aug7_sumc)
axs[2,1].tick_params(axis='x', labelsize=20)

axs[3,0].set_title('Aug 8th', fontdict={'fontsize':30})
axs[3,0].set_ylabel('Dollars ($)', fontdict={'fontsize':30})
axs[3,0].bar(aug8c.columns, aug8_sumc)
axs[3,0].tick_params(axis='x', labelsize=20)
#plt.subplots_adjust(wspace = .5, hspace = .5)
#plt.subplots_adjust(left=0.5, bottom=0.5, right=1, top=1, wspace=0.9,hspace=0.9)
#fig.tight_layout()
plt.show()

# %%
colors = [(0.7969,0,0),(0.9961,0.75,.1484),(0.2031,0.2852,.3672),(0,0,.8),(.7969,.7969,.7969),(0.6445,0.1641,.1641),(0,.5,0),(0.2,0.2,.2)]

# %%
fig, ax = plt.subplots()
plt.stackplot(list(range(1,25)), aug2['Nuclear'], aug2['NG'], aug2['RFO'], aug2['Hydro'], aug2['Coal'], aug2['Wood'], aug2['Wind'], aug2['Other'], labels=['Nuclear', 'NG', 'RFO', 'Hydro', 'Coal', 'Wood', 'Wind', 'Other'], colors = colors)
ax.set_ylabel('MW')
ax.set_xlabel('Hours')
ax.set_title('Aug 2nd Generation Sources')
plt.xlim(0,32)
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
plt.stackplot(list(range(1,25)), aug3['Nuclear'], aug3['NG'], aug3['RFO'], aug3['Hydro'], aug3['Coal'], aug3['Wood'], aug3['Wind'], aug3['Other'], labels=['Nuclear', 'NG', 'RFO', 'Hydro', 'Coal', 'Wood', 'Wind', 'Other'], colors = colors)
ax.set_ylabel('MW')
ax.set_xlabel('Hours')
ax.set_title('Aug 3rd Generation Sources')
plt.xlim(0,32)
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
plt.stackplot(list(range(1,25)), aug2c['Nuclear'], aug2c['NG'], aug2c['RFO'], aug2c['Hydro'], aug2c['Coal'], aug2c['Wood'], aug2c['Wind'], aug2c['Other'], labels=['Nuclear', 'NG', 'RFO', 'Hydro', 'Coal', 'Wood', 'Wind', 'Other'], colors = colors)
ax.set_ylabel('Thousands of Dollars')
ax.set_xlabel('Hours')
ax.set_title('Aug 2nd Generation Sources Cost')
plt.xlim(0,32)
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
plt.stackplot(list(range(1,25)), aug3c['Nuclear'], aug3c['NG'], aug3c['RFO'], aug3c['Hydro'], aug3c['Coal'], aug3c['Wood'], aug3c['Wind'], aug3c['Other'], labels=['Nuclear', 'NG', 'RFO', 'Hydro', 'Coal', 'Wood', 'Wind', 'Other'], colors = colors)
ax.set_ylabel('Thousands of Dollars')
ax.set_xlabel('Hours')
ax.set_title('Aug 3rd Generation Sources Cost')
plt.xlim(0,32)
plt.legend()
plt.show()
